# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y1 = [
    116.6666667, 118.3333333, 115, 118.2222222, 115.1111111, 115,
    119.5555556, 116.6666667, 121.1111111, 116.4444444, 116.4444444, 115.1111111,
    113.5555556, 116.6666667, 113.5555556, 116.6666667, 113.5555556, 119.5555556,
    116.6666667, 115, 116.4444444, 116.6666667, 115.1111111, 116.6666667,
    118.3333333, 122.7777778, 116.5555556, 116.4444444, 115, 118.2222222
]

y2 = [
    110.4444444, 118.1111111, 116.4444444, 116.4444444, 118.3333333, 124.4444444,
    119.5555556, 115, 116.5555556, 121.2222222, 122.6666667, 116.4444444,
    124.2222222, 114.8888889, 118.1111111, 121.1111111, 124.3333333, 116.4444444,
    118, 115, 122.6666667, 121.1111111, 115, 121.1111111, 115.3333333,
    121.2222222, 116.5555556, 119.5555556, 124.2222222, 122.7777778
]

y3 = [
    144.4444444, 143, 140, 135.4444444, 143.4444444, 153.8888889,
    130.5555556, 137.1111111, 147.8888889, 136.6666667, 148.1111111, 149.6666667,
    133.6666667, 133.6666667, 142.8888889, 146.3333333, 147.6666667, 133.6666667,
    142.8888889, 133.5555556, 140, 132.1111111, 127.7777778, 144.5555556,
    143.1111111, 146.2222222, 143.1111111, 143, 136.7777778, 149.2222222
]

# y4 = [
#     77.77777778, 82.33333333, 79.22222222, 79.44444444, 79.44444444,
#     79.33333333, 78, 79.22222222, 79.22222222, 80.77777778,
#     80.77777778, 82.44444444, 83.88888889, 77.66666667, 79.22222222,
#     82.44444444, 79.22222222, 82.33333333, 79.22222222, 79.11111111,
#     79.11111111, 85.33333333, 80.77777778, 85.33333333, 76.33333333,
#     79.33333333, 79.11111111, 77.66666667, 77.66666667, 79.44444444
# ]

# y5 = [
#     93.11111111, 77.55555556, 82.33333333, 80.66666667, 80.88888889,
#     79.55555556, 82.33333333, 91.55555556, 79.22222222, 82.22222222,
#     96.22222222, 74.88888889, 79.22222222, 76.33333333, 74.55555556,
#     81.22222222, 81, 85.77777778, 79.22222222, 87.22222222,
#     77.77777778, 91.88888889, 87, 97.77777778, 82.22222222,
#     79.22222222, 76.33333333, 73, 76.33333333, 76.22222222
# ]

# y6 = [
#     88.55555556, 91.77777778, 90.22222222, 89.11111111, 97,
#     93.33333333, 78.22222222, 94.66666667, 84.11111111, 86.88888889,
#     90.22222222, 87.11111111, 87.11111111, 91.66666667, 87.22222222,
#     94.77777778, 90.33333333, 91.55555556, 102.4444444, 91.66666667,
#     88.44444444, 82.33333333, 79.22222222, 93.11111111, 88.88888889,
#     96.55555556, 94.77777778, 93.44444444, 91.88888889, 86.11111111
# ]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)
# m4, b4 = np.polyfit(x, y4, 1)
# m5, b5 = np.polyfit(x, y5, 1)
# m6, b6 = np.polyfit(x, y6, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3
# best_fit_y4 = m4 * x + b4
# best_fit_y5 = m5 * x + b5
# best_fit_y6 = m6 * x + b6

plt.plot(x, y1, label="shallow4", color="blue")
plt.plot(x, y2, label="default4", color="orange")
plt.plot(x, y3, label="deep4", color="green")
# plt.plot(x, y4, label="shallow5", color="red")
# plt.plot(x, y5, label="default5", color="yellow")
# plt.plot(x, y6, label="deep5", color="purple")

plt.plot(x, best_fit_y1, "--", label="shallow best fit4", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit4", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit4", color="green")
# plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="red")
# plt.plot(x, best_fit_y5, "--", label="default best fit5", color="yellow")
# plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="purple")

plt.xlabel("iteration number")
plt.ylabel("average conditional wait time in rounds")
plt.title("average conditional wait time over 30 iterations in 4 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# print("y4: y =", m4, "* x +", b4)
# print("y5: y =", m5, "* x +", b5)
# print("y6: y =", m6, "* x +", b6)
# Out:
# y1: y = 0.01527623290322847 * x + 116.46692210000003
# y2: y = 0.11711778631813352 * x + 117.09578541540233
# y3: y = -0.02847608404894378 * x + 141.4561941227587

# %%
y4 = [
    77.77777778, 82.33333333, 79.22222222, 79.44444444, 79.44444444,
    79.33333333, 78, 79.22222222, 79.22222222, 80.77777778,
    80.77777778, 82.44444444, 83.88888889, 77.66666667, 79.22222222,
    82.44444444, 79.22222222, 82.33333333, 79.22222222, 79.11111111,
    79.11111111, 85.33333333, 80.77777778, 85.33333333, 76.33333333,
    79.33333333, 79.11111111, 77.66666667, 77.66666667, 79.44444444
]

y5 = [
    93.11111111, 77.55555556, 82.33333333, 80.66666667, 80.88888889,
    79.55555556, 82.33333333, 91.55555556, 79.22222222, 82.22222222,
    96.22222222, 74.88888889, 79.22222222, 76.33333333, 74.55555556,
    81.22222222, 81, 85.77777778, 79.22222222, 87.22222222,
    77.77777778, 91.88888889, 87, 97.77777778, 82.22222222,
    79.22222222, 76.33333333, 73, 76.33333333, 76.22222222
]

y6 = [
    88.55555556, 91.77777778, 90.22222222, 89.11111111, 97,
    93.33333333, 78.22222222, 94.66666667, 84.11111111, 86.88888889,
    90.22222222, 87.11111111, 87.11111111, 91.66666667, 87.22222222,
    94.77777778, 90.33333333, 91.55555556, 102.4444444, 91.66666667,
    88.44444444, 82.33333333, 79.22222222, 93.11111111, 88.88888889,
    96.55555556, 94.77777778, 93.44444444, 91.88888889, 86.11111111
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y4) + 1)

# fit y = mx + b
m4, b4 = np.polyfit(x, y4, 1)
m5, b5 = np.polyfit(x, y5, 1)
m6, b6 = np.polyfit(x, y6, 1)

best_fit_y4 = m4 * x + b4
best_fit_y5 = m5 * x + b5
best_fit_y6 = m6 * x + b6

plt.plot(x, y4, label="shallow5", color="blue")
plt.plot(x, y5, label="default5", color="orange")
plt.plot(x, y6, label="deep5", color="green")

plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="blue")
plt.plot(x, best_fit_y5, "--", label="default best fit5", color="orange")
plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="green")

plt.xlabel("iteration number")
plt.ylabel("average conditional wait time in rounds")
plt.title("average conditional wait time over 30 iterations in 5 processors")
plt.legend()

plt.show()

print("y4: y =", m4, "* x +", b4)
print("y5: y =", m5, "* x +", b5)
print("y6: y =", m6, "* x +", b6)
# Out:
# y4: y = -0.002644914073415492 * x + 80.08173690747128
# y5: y = -0.11731553586651776 * x + 83.91468710193105
# y6: y = 0.04689160787319309 * x + 89.36577266896553

# %%
y1 = [
    116.6666667, 118.3333333, 115, 118.2222222, 115.1111111, 115,
    119.5555556, 116.6666667, 121.1111111, 116.4444444, 116.4444444, 115.1111111,
    113.5555556, 116.6666667, 113.5555556, 116.6666667, 113.5555556, 119.5555556,
    116.6666667, 115, 116.4444444, 116.6666667, 115.1111111, 116.6666667,
    118.3333333, 122.7777778, 116.5555556, 116.4444444, 115, 118.2222222
]

y2 = [
    110.4444444, 118.1111111, 116.4444444, 116.4444444, 118.3333333, 124.4444444,
    119.5555556, 115, 116.5555556, 121.2222222, 122.6666667, 116.4444444,
    124.2222222, 114.8888889, 118.1111111, 121.1111111, 124.3333333, 116.4444444,
    118, 115, 122.6666667, 121.1111111, 115, 121.1111111, 115.3333333,
    121.2222222, 116.5555556, 119.5555556, 124.2222222, 122.7777778
]

y3 = [
    144.4444444, 143, 140, 135.4444444, 143.4444444, 153.8888889,
    130.5555556, 137.1111111, 147.8888889, 136.6666667, 148.1111111, 149.6666667,
    133.6666667, 133.6666667, 142.8888889, 146.3333333, 147.6666667, 133.6666667,
    142.8888889, 133.5555556, 140, 132.1111111, 127.7777778, 144.5555556,
    143.1111111, 146.2222222, 143.1111111, 143, 136.7777778, 149.2222222
]

y4 = [
    77.77777778, 82.33333333, 79.22222222, 79.44444444, 79.44444444,
    79.33333333, 78, 79.22222222, 79.22222222, 80.77777778,
    80.77777778, 82.44444444, 83.88888889, 77.66666667, 79.22222222,
    82.44444444, 79.22222222, 82.33333333, 79.22222222, 79.11111111,
    79.11111111, 85.33333333, 80.77777778, 85.33333333, 76.33333333,
    79.33333333, 79.11111111, 77.66666667, 77.66666667, 79.44444444
]

y5 = [
    93.11111111, 77.55555556, 82.33333333, 80.66666667, 80.88888889,
    79.55555556, 82.33333333, 91.55555556, 79.22222222, 82.22222222,
    96.22222222, 74.88888889, 79.22222222, 76.33333333, 74.55555556,
    81.22222222, 81, 85.77777778, 79.22222222, 87.22222222,
    77.77777778, 91.88888889, 87, 97.77777778, 82.22222222,
    79.22222222, 76.33333333, 73, 76.33333333, 76.22222222
]

y6 = [
    88.55555556, 91.77777778, 90.22222222, 89.11111111, 97,
    93.33333333, 78.22222222, 94.66666667, 84.11111111, 86.88888889,
    90.22222222, 87.11111111, 87.11111111, 91.66666667, 87.22222222,
    94.77777778, 90.33333333, 91.55555556, 102.4444444, 91.66666667,
    88.44444444, 82.33333333, 79.22222222, 93.11111111, 88.88888889,
    96.55555556, 94.77777778, 93.44444444, 91.88888889, 86.11111111
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)
m4, b4 = np.polyfit(x, y4, 1)
m5, b5 = np.polyfit(x, y5, 1)
m6, b6 = np.polyfit(x, y6, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3
best_fit_y4 = m4 * x + b4
best_fit_y5 = m5 * x + b5
best_fit_y6 = m6 * x + b6

plt.plot(x, y1, label="shallow4", color="blue")
plt.plot(x, y2, label="default4", color="orange")
plt.plot(x, y3, label="deep4", color="green")
plt.plot(x, y4, label="shallow5", color="cyan")
plt.plot(x, y5, label="default5", color="moccasin")
plt.plot(x, y6, label="deep5", color="lightgreen")

plt.plot(x, best_fit_y1, "--", label="shallow best fit4", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit4", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit4", color="green")
plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="cyan")
plt.plot(x, best_fit_y5, "--", label="default best fit5", color="moccasin")
plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="lightgreen")

plt.xlabel("iteration number")
plt.ylabel("average conditional wait time in rounds")
plt.title("difference in average conditional wait time over 30 iterations btwn 4 vs 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
print("y4: y =", m4, "* x +", b4)
print("y5: y =", m5, "* x +", b5)
print("y6: y =", m6, "* x +", b6)
# Out:
# y1: y = 0.01527623290322847 * x + 116.46692210000003
# y2: y = 0.11711778631813352 * x + 117.09578541540233
# y3: y = -0.02847608404894378 * x + 141.4561941227587
# y4: y = -0.002644914073415492 * x + 80.08173690747128
# y5: y = -0.11731553586651776 * x + 83.91468710193105
# y6: y = 0.04689160787319309 * x + 89.36577266896553

# %%
y1 = [
    90, 75, 76, 116, 103, 144, 142, 103, 155, 90,
    88, 76, 64, 116, 101, 103, 49, 116, 116, 77,
    77, 129, 90, 129, 50, 129, 89, 38, 116, 78
]

y2 = [
    60, 103, 116, 77, 103, 154, 103, 177, 90, 154,
    141, 177, 285, 141, 103, 142, 194, 116, 77, 142,
    115, 116, 77, 168, 91, 140, 116, 250, 168, 169
]

y3 = [
    358, 438, 575, 617, 349, 895, 277, 482, 555, 509,
    715, 556, 410, 360, 601, 688, 507, 385, 400, 344,
    673, 294, 564, 698, 510, 472, 612, 587, 307, 690
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3

plt.plot(x, y1, label="shallow", color="blue")
plt.plot(x, y2, label="default", color="orange")
plt.plot(x, y3, label="deep", color="green")

plt.plot(x, best_fit_y1, "--", label="shallow best fit", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit", color="green")

plt.xlabel("iteration number")
plt.ylabel("wasted decode volume")
plt.yticks(np.arange(0, 1000, 100))
plt.title("wasted decode volume over 30 iterations in 4 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# Out:
# y1: y = -0.6022246941045585 * x + 106.83448275862067
# y2: y = 1.5392658509454957 * x + 111.64137931034485
# y3: y = 0.95973303670745 * x + 499.3908045977013

# %%
# y1 = [
#     90, 75, 76, 116, 103, 144, 142, 103, 155, 90,
#     88, 76, 64, 116, 101, 103, 49, 116, 116, 77,
#     77, 129, 90, 129, 50, 129, 89, 38, 116, 78
# ]

# y2 = [
#     60, 103, 116, 77, 103, 154, 103, 177, 90, 154,
#     141, 177, 285, 141, 103, 142, 194, 116, 77, 142,
#     115, 116, 77, 168, 91, 140, 116, 250, 168, 169
# ]

# y3 = [
#     358, 438, 575, 617, 349, 895, 277, 482, 555, 509,
#     715, 556, 410, 360, 601, 688, 507, 385, 400, 344,
#     673, 294, 564, 698, 510, 472, 612, 587, 307, 690
# ]

y4 = [
    177, 220, 149, 201, 154, 88, 104, 128, 102, 193,
    141, 114, 180, 88, 76, 179, 182, 141, 76, 126,
    167, 167, 168, 166, 153, 167, 115, 89, 101, 114
]

y5 = [
    508, 512, 126, 414, 165, 97, 193, 248, 348, 126,
    269, 398, 179, 340, 112, 169, 120, 153, 177, 460,
    344, 347, 335, 173, 128, 141, 104, 332, 155, 123
]

y6 = [
    236, 312, 230, 237, 260, 289, 117, 299, 488, 384,
    358, 210, 208, 355, 263, 532, 331, 208, 629, 222,
    248, 316, 209, 277, 354, 250, 570, 330, 212, 254
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y4) + 1)

# fit y = mx + b
# m1, b1 = np.polyfit(x, y1, 1)
# m2, b2 = np.polyfit(x, y2, 1)
# m3, b3 = np.polyfit(x, y3, 1)
m4, b4 = np.polyfit(x, y4, 1)
m5, b5 = np.polyfit(x, y5, 1)
m6, b6 = np.polyfit(x, y6, 1)

# best_fit_y1 = m1 * x + b1
# best_fit_y2 = m2 * x + b2
# best_fit_y3 = m3 * x + b3
best_fit_y4 = m4 * x + b4
best_fit_y5 = m5 * x + b5
best_fit_y6 = m6 * x + b6

# plt.plot(x, y1, label="shallow4", color="blue")
# plt.plot(x, y2, label="default4", color="orange")
# plt.plot(x, y3, label="deep4", color="green")
plt.plot(x, y4, label="shallow5", color="blue")
plt.plot(x, y5, label="default5", color="orange")
plt.plot(x, y6, label="deep5", color="green")

# plt.plot(x, best_fit_y1, "--", label="shallow best fit4", color="blue")
# plt.plot(x, best_fit_y2, "--", label="default best fit4", color="orange")
# plt.plot(x, best_fit_y3, "--", label="deep best fit4", color="green")
plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="blue")
plt.plot(x, best_fit_y5, "--", label="default best fit5", color="orange")
plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="green")

plt.xlabel("iteration number")
plt.ylabel("wasted decode volume")
plt.title("wasted decode volume in 5 processors")
plt.legend()

plt.show()

# print("y1: y =", m1, "* x +", b1)
# print("y2: y =", m2, "* x +", b2)
# print("y3: y =", m3, "* x +", b3)
print("y4: y =", m4, "* x +", b4)
print("y5: y =", m5, "* x +", b5)
print("y6: y =", m6, "* x +", b6)
# Out:
# y4: y = -1.114126807563958 * x + 158.13563218390803
# y5: y = -4.429365962180198 * x + 311.85517241379324
# y6: y = 1.9021134593993365 * x + 276.7839080459771

# %%
y1 = [
    90, 75, 76, 116, 103, 144, 142, 103, 155, 90,
    88, 76, 64, 116, 101, 103, 49, 116, 116, 77,
    77, 129, 90, 129, 50, 129, 89, 38, 116, 78
]

y2 = [
    60, 103, 116, 77, 103, 154, 103, 177, 90, 154,
    141, 177, 285, 141, 103, 142, 194, 116, 77, 142,
    115, 116, 77, 168, 91, 140, 116, 250, 168, 169
]

y3 = [
    358, 438, 575, 617, 349, 895, 277, 482, 555, 509,
    715, 556, 410, 360, 601, 688, 507, 385, 400, 344,
    673, 294, 564, 698, 510, 472, 612, 587, 307, 690
]

y4 = [
    177, 220, 149, 201, 154, 88, 104, 128, 102, 193,
    141, 114, 180, 88, 76, 179, 182, 141, 76, 126,
    167, 167, 168, 166, 153, 167, 115, 89, 101, 114
]

y5 = [
    508, 512, 126, 414, 165, 97, 193, 248, 348, 126,
    269, 398, 179, 340, 112, 169, 120, 153, 177, 460,
    344, 347, 335, 173, 128, 141, 104, 332, 155, 123
]

y6 = [
    236, 312, 230, 237, 260, 289, 117, 299, 488, 384,
    358, 210, 208, 355, 263, 532, 331, 208, 629, 222,
    248, 316, 209, 277, 354, 250, 570, 330, 212, 254
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)
m4, b4 = np.polyfit(x, y4, 1)
m5, b5 = np.polyfit(x, y5, 1)
m6, b6 = np.polyfit(x, y6, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3
best_fit_y4 = m4 * x + b4
best_fit_y5 = m5 * x + b5
best_fit_y6 = m6 * x + b6

plt.plot(x, y1, label="shallow4", color="blue")
plt.plot(x, y2, label="default4", color="orange")
plt.plot(x, y3, label="deep4", color="green")
plt.plot(x, y4, label="shallow5", color="cyan")
plt.plot(x, y5, label="default5", color="moccasin")
plt.plot(x, y6, label="deep5", color="lightgreen")

plt.plot(x, best_fit_y1, "--", label="shallow best fit4", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit4", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit4", color="green")
plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="cyan")
plt.plot(x, best_fit_y5, "--", label="default best fit5", color="moccasin")
plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="lightgreen")

plt.xlabel("iteration number")
plt.ylabel("wasted decode volume")
plt.title("difference in wasted decode volume btwn 4 vs 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
print("y4: y =", m4, "* x +", b4)
print("y5: y =", m5, "* x +", b5)
print("y6: y =", m6, "* x +", b6)
# Out:
# y1: y = -0.6022246941045585 * x + 106.83448275862067
# y2: y = 1.5392658509454957 * x + 111.64137931034485
# y3: y = 0.95973303670745 * x + 499.3908045977013
# y4: y = -1.114126807563958 * x + 158.13563218390803
# y5: y = -4.429365962180198 * x + 311.85517241379324
# y6: y = 1.9021134593993365 * x + 276.7839080459771

# %%
y1 = [
    7, 12, 7, 9, 8, 9, 11, 8, 12, 7,
    13, 7, 5, 9, 10, 8, 6, 9, 9, 6,
    6, 10, 7, 10, 7, 10, 8, 6, 9, 9
]

y2 = [
    9, 8, 9, 6, 12, 13, 8, 19, 7, 12,
    12, 18, 22, 11, 8, 11, 15, 9, 6, 11,
    10, 9, 7, 13, 10, 13, 9, 15, 13, 12
]

y3 = [
    19, 23, 25, 26, 20, 27, 15, 25, 31, 22,
    28, 22, 22, 18, 27, 27, 24, 20, 20, 19,
    26, 14, 24, 29, 21, 32, 30, 28, 15, 28
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3

plt.plot(x, y1, label="shallow", color="blue")
plt.plot(x, y2, label="default", color="orange")
plt.plot(x, y3, label="deep", color="green")

plt.plot(x, best_fit_y1, "--", label="shallow best fit", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit", color="green")

plt.xlabel("iteration number")
plt.ylabel("num mispredictions")
plt.title("num mispredictions over 30 iterations")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# Out:
# y1: y = -0.03915461624026686 * x + 9.073563218390806
# y2: y = 0.03804226918798678 * x + 10.643678160919544
# y3: y = 0.06874304783092337 * x + 22.501149425287363
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
y1 = [
    17, 16, 17, 21, 12, 8, 11, 10, 8, 15,
    11, 10, 14, 8, 6, 15, 12, 11, 6, 12,
    13, 13, 12, 14, 13, 13, 9, 7, 9, 15
]

y2 = [
    22, 18, 12, 17, 15, 17, 15, 15, 13, 12,
    20, 11, 17, 13, 12, 18, 17, 18, 16, 19,
    15, 20, 13, 20, 10, 11, 11, 16, 16, 18
]

y3 = [
    14, 22, 20, 20, 19, 16, 11, 20, 18, 20,
    18, 12, 13, 21, 15, 26, 22, 13, 26, 13,
    16, 17, 12, 15, 23, 15, 30, 17, 16, 16
]
# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3

plt.plot(x, y1, label="shallow5", color="blue")
plt.plot(x, y2, label="default5", color="orange")
plt.plot(x, y3, label="deep5", color="green")

plt.plot(x, best_fit_y1, "--", label="shallow best fit5", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit5", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit5", color="green")

plt.xlabel("iteration number")
plt.ylabel("num mispredictions 5")
plt.title("num mispredictions in 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# Out:
# y1: y = -0.12146829810900997 * x + 13.816091954022994
# y2: y = -0.04382647385984425 * x + 16.245977011494254
# y3: y = 0.012903225806451714 * x + 17.666666666666675

# %%
y1 = [
    7, 12, 7, 9, 8, 9, 11, 8, 12, 7,
    13, 7, 5, 9, 10, 8, 6, 9, 9, 6,
    6, 10, 7, 10, 7, 10, 8, 6, 9, 9
]

y2 = [
    9, 8, 9, 6, 12, 13, 8, 19, 7, 12,
    12, 18, 22, 11, 8, 11, 15, 9, 6, 11,
    10, 9, 7, 13, 10, 13, 9, 15, 13, 12
]

y3 = [
    19, 23, 25, 26, 20, 27, 15, 25, 31, 22,
    28, 22, 22, 18, 27, 27, 24, 20, 20, 19,
    26, 14, 24, 29, 21, 32, 30, 28, 15, 28
]

y4 = [
    17, 16, 17, 21, 12, 8, 11, 10, 8, 15,
    11, 10, 14, 8, 6, 15, 12, 11, 6, 12,
    13, 13, 12, 14, 13, 13, 9, 7, 9, 15
]

y5 = [
    22, 18, 12, 17, 15, 17, 15, 15, 13, 12,
    20, 11, 17, 13, 12, 18, 17, 18, 16, 19,
    15, 20, 13, 20, 10, 11, 11, 16, 16, 18
]

y6 = [
    14, 22, 20, 20, 19, 16, 11, 20, 18, 20,
    18, 12, 13, 21, 15, 26, 22, 13, 26, 13,
    16, 17, 12, 15, 23, 15, 30, 17, 16, 16
]
# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)
m4, b4 = np.polyfit(x, y4, 1)
m5, b5 = np.polyfit(x, y5, 1)
m6, b6 = np.polyfit(x, y6, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3
best_fit_y4 = m4 * x + b4
best_fit_y5 = m5 * x + b5
best_fit_y6 = m6 * x + b6

plt.plot(x, y1, label="shallow4", color="blue")
plt.plot(x, y2, label="default4", color="orange")
plt.plot(x, y3, label="deep4", color="green")
plt.plot(x, y4, label="shallow5", color="cyan")
plt.plot(x, y5, label="default5", color="moccasin")
plt.plot(x, y6, label="deep5", color="lightgreen")

plt.plot(x, best_fit_y1, "--", label="shallow best fit4", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit4", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit4", color="green")
plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="cyan")
plt.plot(x, best_fit_y5, "--", label="default best fit5", color="moccasin")
plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="lightgreen")

plt.xlabel("iteration number")
plt.ylabel("num mispredictions")
plt.title("difference in num mispredictions btwn 4 vs 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
print("y4: y =", m4, "* x +", b4)
print("y5: y =", m5, "* x +", b5)
print("y6: y =", m6, "* x +", b6)
# Out:
# y1: y = -0.03915461624026686 * x + 9.073563218390806
# y2: y = 0.03804226918798678 * x + 10.643678160919544
# y3: y = 0.06874304783092337 * x + 22.501149425287363
# y4: y = -0.12146829810900997 * x + 13.816091954022994
# y5: y = -0.04382647385984425 * x + 16.245977011494254
# y6: y = 0.012903225806451714 * x + 17.666666666666675
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
y1 = [
    378, 349, 335, 353, 304, 351, 365, 318, 380, 378,
    353, 347, 324, 349, 334, 318, 307, 358, 378, 338,
    377, 332, 317, 361, 332, 372, 352, 351, 352, 346
]

y2 = [
    432, 460, 447, 420, 457, 489, 461, 438, 431, 485,
    476, 467, 525, 458, 434, 475, 503, 434, 434, 434,
    459, 462, 430, 476, 404, 496, 460, 476, 515, 463
]

y3 = [
    446, 486, 456, 471, 414, 593, 397, 520, 507, 415,
    467, 451, 469, 391, 443, 508, 462, 403, 465, 440,
    499, 427, 421, 579, 469, 491, 483, 500, 405, 472
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3

plt.plot(x, y1, label="shallow", color="blue")
plt.plot(x, y2, label="default", color="orange")
plt.plot(x, y3, label="deep", color="green")

plt.plot(x, best_fit_y1, "--", label="shallow best fit", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit", color="green")

plt.xlabel("iteration number")
plt.ylabel("rounds w/ only unwanted idles")
plt.title("rounds w/ only unwanted idles in 4 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# Out:
# y1: y = -0.002447163515015482 * x + 347.0045977011496
# y2: y = 0.5777530589543988 * x + 451.0781609195404
# y3: y = 0.11123470522803514 * x + 463.2758620689656
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
y1 = [
    159, 207, 168, 198, 160, 175, 198, 180, 164, 192,
    150, 162, 206, 157, 163, 162, 202, 207, 164, 186,
    178, 207, 150, 147, 168, 202, 180, 189, 186, 186
]

y2 = [
    260, 226, 213, 243, 215, 179, 232, 286, 215, 216,
    327, 213, 194, 215, 193, 202, 200, 256, 215, 260,
    226, 240, 244, 298, 217, 190, 192, 235, 214, 182
]

y3 = [
    249, 190, 192, 242, 179, 178, 209, 257, 250, 192,
    211, 222, 151, 224, 222, 188, 157, 229, 229, 189,
    197, 230, 126, 237, 200, 206, 241, 247, 179, 194
]
# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3

plt.plot(x, y1, label="shallow", color="blue")
plt.plot(x, y2, label="default", color="orange")
plt.plot(x, y3, label="deep", color="green")

plt.plot(x, best_fit_y1, "--", label="shallow best fit", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit", color="green")

plt.xlabel("iteration number")
plt.ylabel("rounds w/ only unwanted idles")
plt.title("rounds w/ only unwanted idles in 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# Out:
# y1: y = 0.1426028921023342 * x + 176.22298850574722
# y2: y = -0.5339265850945499 * x + 234.87586206896557
# y3: y = -0.2765294771968811 * x + 211.5195402298851

# %%
y1 = [
    378, 349, 335, 353, 304, 351, 365, 318, 380, 378,
    353, 347, 324, 349, 334, 318, 307, 358, 378, 338,
    377, 332, 317, 361, 332, 372, 352, 351, 352, 346
]

y2 = [
    432, 460, 447, 420, 457, 489, 461, 438, 431, 485,
    476, 467, 525, 458, 434, 475, 503, 434, 434, 434,
    459, 462, 430, 476, 404, 496, 460, 476, 515, 463
]

y3 = [
    446, 486, 456, 471, 414, 593, 397, 520, 507, 415,
    467, 451, 469, 391, 443, 508, 462, 403, 465, 440,
    499, 427, 421, 579, 469, 491, 483, 500, 405, 472
]

y4 = [
    159, 207, 168, 198, 160, 175, 198, 180, 164, 192,
    150, 162, 206, 157, 163, 162, 202, 207, 164, 186,
    178, 207, 150, 147, 168, 202, 180, 189, 186, 186
]

y5 = [
    260, 226, 213, 243, 215, 179, 232, 286, 215, 216,
    327, 213, 194, 215, 193, 202, 200, 256, 215, 260,
    226, 240, 244, 298, 217, 190, 192, 235, 214, 182
]

y6 = [
    249, 190, 192, 242, 179, 178, 209, 257, 250, 192,
    211, 222, 151, 224, 222, 188, 157, 229, 229, 189,
    197, 230, 126, 237, 200, 206, 241, 247, 179, 194
]
# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)
m4, b4 = np.polyfit(x, y4, 1)
m5, b5 = np.polyfit(x, y5, 1)
m6, b6 = np.polyfit(x, y6, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3
best_fit_y4 = m4 * x + b4
best_fit_y5 = m5 * x + b5
best_fit_y6 = m6 * x + b6

plt.plot(x, y1, label="shallow4", color="blue")
plt.plot(x, y2, label="default4", color="orange")
plt.plot(x, y3, label="deep4", color="green")
plt.plot(x, y4, label="shallow5", color="cyan")
plt.plot(x, y5, label="default5", color="moccasin")
plt.plot(x, y6, label="deep5", color="lightgreen")

plt.plot(x, best_fit_y1, "--", label="shallow best fit4", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit4", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit4", color="green")
plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="cyan")
plt.plot(x, best_fit_y5, "--", label="default best fit5", color="moccasin")
plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="lightgreen")

plt.xlabel("iteration number")
plt.ylabel("rounds w/ only unwanted idles")
plt.title("difference in rounds w/ only unwanted idles btwn 4 vs 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
print("y4: y =", m4, "* x +", b4)
print("y5: y =", m5, "* x +", b5)
print("y6: y =", m6, "* x +", b6)
# Out:
# y1: y = -0.002447163515015482 * x + 347.0045977011496
# y2: y = 0.5777530589543988 * x + 451.0781609195404
# y3: y = 0.11123470522803514 * x + 463.2758620689656
# y4: y = 0.1426028921023342 * x + 176.22298850574722
# y5: y = -0.5339265850945499 * x + 234.87586206896557
# y6: y = -0.2765294771968811 * x + 211.5195402298851
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
y1 = [
    812, 813, 798, 826, 798, 826, 840, 812, 840, 812,
    813, 798, 784, 826, 798, 812, 784, 826, 812, 798,
    798, 826, 798, 812, 799, 840, 812, 798, 812, 813
]

y2 = [
    770, 812, 812, 798, 814, 854, 826, 826, 812, 854,
    854, 827, 896, 812, 812, 840, 868, 812, 812, 812,
    854, 840, 799, 854, 799, 840, 812, 840, 868, 854
]

y3 = [
    966, 980, 966, 938, 953, 1050, 896, 953, 1022, 952,
    1008, 995, 938, 924, 994, 1008, 1008, 924, 966, 924,
    980, 896, 910, 1008, 966, 1008, 1008, 1008, 938, 1023
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3

plt.plot(x, y1, label="shallow", color="blue")
plt.plot(x, y2, label="default", color="orange")
plt.plot(x, y3, label="deep", color="green")

plt.plot(x, best_fit_y1, "--", label="shallow best fit", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit", color="green")

plt.xlabel("iteration number")
plt.ylabel("total num rounds")
plt.title("total num rounds in 4 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# Out:
# y1: y = -0.2028921023359171 * x + 814.3448275862072
# y2: y = 0.9341490545050127 * x + 814.9540229885058
# y3: y = 0.4235817575083488 * x + 963.7678160919543

# %%
y1 = [
    546, 560, 532, 546, 532, 518, 519, 518, 518, 546,
    532, 532, 546, 504, 504, 546, 546, 532, 504, 532,
    532, 560, 546, 560, 518, 532, 518, 504, 504, 519
]

y2 = [
    602, 532, 532, 546, 532, 519, 546, 588, 532, 532,
    602, 519, 532, 519, 504, 520, 532, 547, 532, 575,
    532, 575, 560, 602, 532, 532, 505, 518, 519, 505
]

y3 = [
    574, 602, 588, 562, 602, 588, 519, 602, 561, 574,
    588, 560, 560, 602, 560, 616, 588, 588, 658, 574,
    560, 560, 518, 588, 588, 602, 616, 588, 575, 561
]

# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3

plt.plot(x, y1, label="shallow", color="blue")
plt.plot(x, y2, label="default", color="orange")
plt.plot(x, y3, label="deep", color="green")

plt.plot(x, best_fit_y1, "--", label="shallow best fit", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit", color="green")

plt.xlabel("iteration number")
plt.ylabel("total num rounds")
plt.title("total num rounds in 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
# Out:
# y1: y = -0.4956618464961057 * x + 537.8827586206897
# y2: y = -0.6987764182424936 * x + 551.5977011494256
# y3: y = 0.13259176863181715 * x + 578.6781609195403

# %%
y1 = [
    812, 813, 798, 826, 798, 826, 840, 812, 840, 812,
    813, 798, 784, 826, 798, 812, 784, 826, 812, 798,
    798, 826, 798, 812, 799, 840, 812, 798, 812, 813
]

y2 = [
    770, 812, 812, 798, 814, 854, 826, 826, 812, 854,
    854, 827, 896, 812, 812, 840, 868, 812, 812, 812,
    854, 840, 799, 854, 799, 840, 812, 840, 868, 854
]

y3 = [
    966, 980, 966, 938, 953, 1050, 896, 953, 1022, 952,
    1008, 995, 938, 924, 994, 1008, 1008, 924, 966, 924,
    980, 896, 910, 1008, 966, 1008, 1008, 1008, 938, 1023
]

y4 = [
    546, 560, 532, 546, 532, 518, 519, 518, 518, 546,
    532, 532, 546, 504, 504, 546, 546, 532, 504, 532,
    532, 560, 546, 560, 518, 532, 518, 504, 504, 519
]

y5 = [
    602, 532, 532, 546, 532, 519, 546, 588, 532, 532,
    602, 519, 532, 519, 504, 520, 532, 547, 532, 575,
    532, 575, 560, 602, 532, 532, 505, 518, 519, 505
]

y6 = [
    574, 602, 588, 562, 602, 588, 519, 602, 561, 574,
    588, 560, 560, 602, 560, 616, 588, 588, 658, 574,
    560, 560, 518, 588, 588, 602, 616, 588, 575, 561
]
# x = list(range(1, len(y1) + 1))
x = np.arange(1, len(y1) + 1)

# fit y = mx + b
m1, b1 = np.polyfit(x, y1, 1)
m2, b2 = np.polyfit(x, y2, 1)
m3, b3 = np.polyfit(x, y3, 1)
m4, b4 = np.polyfit(x, y4, 1)
m5, b5 = np.polyfit(x, y5, 1)
m6, b6 = np.polyfit(x, y6, 1)

best_fit_y1 = m1 * x + b1
best_fit_y2 = m2 * x + b2
best_fit_y3 = m3 * x + b3
best_fit_y4 = m4 * x + b4
best_fit_y5 = m5 * x + b5
best_fit_y6 = m6 * x + b6

plt.plot(x, y1, label="shallow4", color="blue")
plt.plot(x, y2, label="default4", color="orange")
plt.plot(x, y3, label="deep4", color="green")
plt.plot(x, y4, label="shallow5", color="cyan")
plt.plot(x, y5, label="default5", color="moccasin")
plt.plot(x, y6, label="deep5", color="lightgreen")

plt.plot(x, best_fit_y1, "--", label="shallow best fit4", color="blue")
plt.plot(x, best_fit_y2, "--", label="default best fit4", color="orange")
plt.plot(x, best_fit_y3, "--", label="deep best fit4", color="green")
plt.plot(x, best_fit_y4, "--", label="shallow best fit5", color="cyan")
plt.plot(x, best_fit_y5, "--", label="default best fit5", color="moccasin")
plt.plot(x, best_fit_y6, "--", label="deep best fit5", color="lightgreen")

plt.xlabel("iteration number")
plt.ylabel("total num rounds")
plt.title("difference in total num rounds btwn 4 vs 5 processors")
plt.legend()

plt.show()

print("y1: y =", m1, "* x +", b1)
print("y2: y =", m2, "* x +", b2)
print("y3: y =", m3, "* x +", b3)
print("y4: y =", m4, "* x +", b4)
print("y5: y =", m5, "* x +", b5)
print("y6: y =", m6, "* x +", b6)
# Out:
# y1: y = -0.2028921023359171 * x + 814.3448275862072
# y2: y = 0.9341490545050127 * x + 814.9540229885058
# y3: y = 0.4235817575083488 * x + 963.7678160919543
# y4: y = -0.4956618464961057 * x + 537.8827586206897
# y5: y = -0.6987764182424936 * x + 551.5977011494256
# y6: y = 0.13259176863181715 * x + 578.6781609195403
